# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/RAW_DATA_ALL (3).csv')

# %%
df
# Out:
#      Unnamed: 0  index                                         book_title  \
# 0             0    300  Siege and Storm (The Shadow and Bone Trilogy, #2)
# 1             1    301                       Wait for It (Kindle Edition)
# 2             2    302       Undercover Bromance (Bromance Book Club, #2)
# 3             3    303                   The Cheat Sheet (Kindle Edition)
# 4             4    304            Something Borrowed (Darcy & Rachel, #1)
# ..          ...    ...                                                ...
# 854         257    294      Delilah Green Doesn't Care (Bright Falls, #1)
# 855         258    295           The Governess Game (Girl Meets Duke, #2)
# 856         259    296                           Midnight Sun (Hardcover)
# 857         260    297             Empire of Storms (Throne of Glass, #5)
# 858         261    299                              Darkfever (Fever, #1)
#
#      author_id  Year released  Rating   ratings
# ...

# %%
#statistcal summary

# %%
plt.figure(figsize=(5,5))
plt.subplot(1,2,1)
sns.histplot(df.Rating)
plt.subplot(1,2,2)
sns.histplot(df.ratings)
# Out:
# <Axes: xlabel='ratings', ylabel='Count'>

# %%
df1=df[df.Rating>4.5]
df1.sort_values(by='Rating',ascending=False,inplace=True)
df1
# Out:
# <ipython-input-76-cf4d061d0d3a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.sort_values(by='Rating',ascending=False,inplace=True)
#      Unnamed: 0  index                                     book_title  \
# 729         132    149   Heartstopper: Volume Four (Heartstopper, #4)
# 471         209    845        It Starts with Us (It Ends with Us, #2)
# 678          81     93  Heartstopper: Volume Three (Heartstopper, #3)
# 187         187    517           Kingdom of Ash (Throne of Glass, #7)
# 313          51    667             Crooked Kingdom (Six of Crows, #2)
# 660          63     73    Heartstopper: Volume Two (Heartstopper, #2)
# 857         260    297         Empire of Storms (Throne of Glass, #5)
# 844         247    283         Queen of Shadows (Throne of Glass, #4)
# ...

# %%
#Ratings>4.5,Top 10 rated book
plt.xticks(rotation=90)
plt.yticks(ticks=np.arange(0,5,.5))
sns.barplot(x=df1.book_title,y=df1.Rating,data=df1,orient='v').set_title('Top 10 rated books')
# Out:
# Text(0.5, 1.0, 'Top 10 rated books')

# %%
#No of rating > 400000
df2=df[df.ratings>40000]
df2.sort_values(by='ratings',ascending=False,inplace=True)
df2.head(20)
df2.ratings.sort_values(ascending=False)
df2x=df2.head(10)
df2x
# Out:
# <ipython-input-103-f9734a987142>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.sort_values(by='ratings',ascending=False,inplace=True)
#      Unnamed: 0  index                                book_title  author_id  \
# 656          59     68   The Hunger Games (The Hunger Games, #1)       41.0
# 709         112    128              The Great Gatsby (Paperback)      292.0
# 597           0      1        The Fault in Our Stars (Hardcover)        1.0
# 653          56     65                 Divergent (Divergent, #1)       39.0
# 692          95    108      Catching Fire (The Hunger Games, #2)       41.0
# 624          27     33  Romeo and Juliet (Mass Market Paperback)       27.0
# 604           7     11   Fifty Shades of Grey (Fifty Shades, #1)       10.0
# ...

# %%
plt.xticks(rotation=90)
sns.barplot(x='book_title',y='ratings',data=df2x,orient='v').set_title('Top highly reviewed 10 books')
# Out:
# Text(0.5, 1.0, 'Top highly reviewed 10 books')

# %%
df3=df.author_id.value_counts()
df3_re=df3.reset_index()
df3_re.columns=['author_id','count']
df3_re.author_id.astype('str')
df3_re1=df3_re.sort_values(by='count',ascending=False)
df3_re1
# Out:
#      author_id  count
# 0        292.0     48
# 1         93.0     26
# 2        300.0     23
# 3         68.0     20
# 4          7.0     17
# ..         ...    ...
# 308      145.0      1
# 309      146.0      1
# 310      147.0      1
# 311      152.0      1
# 312      155.0      1
#
# [313 rows x 2 columns]

# %%
df4=df3_re1.head(5)
df4.author_id=df4.author_id.astype('str')
# Out:
# <ipython-input-66-ed650faf2146>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.author_id=df4.author_id.astype('str')

# %%
sns.barplot(x='author_id',y='count',data=df4,color='red').set_title('Top 5 Publishing Author id')
# Out:
# Text(0.5, 1.0, 'Top 5 Publishing Authors')

# %%
df
# Out:
#      Unnamed: 0  index                                         book_title  \
# 0             0    300  Siege and Storm (The Shadow and Bone Trilogy, #2)
# 1             1    301                       Wait for It (Kindle Edition)
# 2             2    302       Undercover Bromance (Bromance Book Club, #2)
# 3             3    303                   The Cheat Sheet (Kindle Edition)
# 4             4    304            Something Borrowed (Darcy & Rachel, #1)
# ..          ...    ...                                                ...
# 854         257    294      Delilah Green Doesn't Care (Bright Falls, #1)
# 855         258    295           The Governess Game (Girl Meets Duke, #2)
# 856         259    296                           Midnight Sun (Hardcover)
# 857         260    297             Empire of Storms (Throne of Glass, #5)
# 858         261    299                              Darkfever (Fever, #1)
#
#      author_id  Year released  Rating   ratings
# ...

# %%
df.rename(columns={'ratings':'No of ratings'},inplace=True)
sns.scatterplot(x='Rating',y='No of ratings',hue='Year released',palette='coolwarm',data=df).set_title('Rating vs No of ratings')
# Out:
# Text(0.5, 1.0, 'Rating vs No of ratings')

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation=45)
sns.countplot(y='Year released', palette='viridis',data=df,orient='h').set_title('No of books published each year')
# Out:
# <ipython-input-113-dd37ef7bd434>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Year released', palette='viridis',data=df,orient='h').set_title('No of books published each year')
# Text(0.5, 1.0, 'No of books published each year')

# %%
import sqlite3
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Connect to the database
conn = sqlite3.connect("/content/authors.db")

# %%
db_cursor = conn.cursor()

# %%
db_cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(db_cursor.fetchall())
# Out:
# [('author',)]

# %%
query = '''
SELECT *
FROM author

'''
df=pd.read_sql(query, conn)
df.to_csv('author.csv', index=False)

# %%
query='''
SELECT *
FROM author
'''
df1=pd.read_sql(query, conn)
df1.to_csv('books.csv', index=False)

# %%
df1=pd.read_csv('/content/RAW_DATA_ALL (3).csv')
df1
# Out:
#      Unnamed: 0  index                                         book_title  \
# 0             0    300  Siege and Storm (The Shadow and Bone Trilogy, #2)
# 1             1    301                       Wait for It (Kindle Edition)
# 2             2    302       Undercover Bromance (Bromance Book Club, #2)
# 3             3    303                   The Cheat Sheet (Kindle Edition)
# 4             4    304            Something Borrowed (Darcy & Rachel, #1)
# ..          ...    ...                                                ...
# 854         257    294      Delilah Green Doesn't Care (Bright Falls, #1)
# 855         258    295           The Governess Game (Girl Meets Duke, #2)
# 856         259    296                           Midnight Sun (Hardcover)
# 857         260    297             Empire of Storms (Throne of Glass, #5)
# 858         261    299                              Darkfever (Fever, #1)
#
#      author_id  Year released  Rating   ratings
# ...

# %%
final=df.join(df1)

# %%
final.drop('Unnamed: 0', axis=1, inplace=True)

# %%
a=final.sort_values(by='Rating',ascending=False).head(10)
plt.xticks(rotation=90)
plt.yticks()
sns.barplot(x='name', y='Rating',data=a,orient='h').set_title('Top 10 Highest Rated authors')
# Out:
# Text(0.5, 1.0, 'Top 10 Highest Rated authors')

# %%
df4=df3_re1.join(final.name)
df4
# Out:
#      author_id  count                  name
# 0        292.0     48           Jane Austen
# 1         93.0     26            John Green
# 2        300.0     23       Casey McQuiston
# 3         68.0     20       Stephenie Meyer
# 4          7.0     17         Sally  Thorne
# ..         ...    ...                   ...
# 308      145.0      1  (Editor/Contributer)
# 309      146.0      1            Tara Sivec
# 310      147.0      1             S.T. Abby
# 311      152.0      1       Kacen Callender
# 312      155.0      1           Mary Balogh
#
# [313 rows x 3 columns]

# %%
plt.xticks(rotation=90)
sns.barplot(x='name',y='count',data=df4.head(5),color='red').set_title('Top 5 Publishing Authors')
# Out:
# Text(0.5, 1.0, 'Top 5 Publishing Authors')
